# %%
import cv2
import os
import numpy as np
img_path = './../Data/images/squirrel.jpg'
image = cv2.imread(img_path)
image.shape
path = './../Data/'

# %% [markdown]
# Reading Images

# %%
image_path = os.path.join(path,'images','squirrel.png')
img = cv2.imread(image_path)

# %% [markdown]
# Wrting an Image

# %%
cv2.imwrite(os.path.join(path,'images','squirrel_out.jpg'),img)
# Out:
# True

# %%
cv2.imshow('farme',img)
cv2.waitKey(0)
# Out:
# 48

# %% [markdown]
# Resizing images

# %%
image_path = os.path.join(path,'images','squirrel.png')
img = cv2.imread(image_path)
resized_img = cv2.resize(img,(300,200))
print(img.shape, resized_img.shape)
cv2.imshow('img',img)
cv2.imshow('resized img',resized_img)
cv2.waitKey(0)
# Out:
# (2592, 3888, 3) (200, 300, 3)
# 48

# %% [markdown]
# Cropping Images in open CV

# %%
image_path = os.path.join(path,'images','squirrel.png')
img = cv2.imread(image_path)
print(img.shape)
crop_img = img[500:2000,800:3000]

cv2.imshow('img',img)
cv2.imshow('cropped img',crop_img)
cv2.waitKey(0)
# Out:
# (2592, 3888, 3)
# -1

# %% [markdown]
# Colorspaces in opencv

# %%
image_path = os.path.join(path,'images','parrot.png')
img = cv2.imread(image_path)
img.shape
# img = cv2.resize(img, (1290,1944))
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) 
img_hvs = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)  
cv2.imshow('img',img)
cv2.imshow('img_RGB',img_rgb)
cv2.imshow('img_gray',img_gray)
cv2.imshow('img_hvs',img_hvs)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# Blurring

# %%
image_path = os.path.join(path,'images','person.png')
img = cv2.imread(image_path)
img.shape
k_size = 7
blurred_image = cv2.blur(img, (k_size,k_size))
gaussian_blur  = cv2.GaussianBlur(img, (k_size,k_size), 5)
median_blur  = cv2.medianBlur(img,k_size)
cv2.imshow('original', img)
cv2.imshow('blurred ', blurred_image)
cv2.imshow('Gaussian Blur', gaussian_blur)
cv2.imshow('Media Blur', median_blur)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# Removing Noise with Blur

# %%
image_path = os.path.join(path,'images','dog.png')
img = cv2.imread(image_path)
k_size = 7
blurred_image = cv2.blur(img, (k_size,k_size))
gaussian_blur  = cv2.GaussianBlur(img, (k_size,k_size), 5)
median_blur  = cv2.medianBlur(img,k_size)
cv2.imshow('original', img)
cv2.imshow('blurred ', blurred_image)
cv2.imshow('Gaussian Blur', gaussian_blur)
cv2.imshow('Media Blur', median_blur)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# Thresholding

# %%
#simple threshold and adaptivethreshold 

image_path = os.path.join(path,'images','parrot.png')
img = cv2.imread(image_path)

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh = cv2.threshold(img_gray, 80, 255, cv2.THRESH_BINARY)
adaptive_thress = cv2.adaptiveThreshold(img_gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 21,30)
cv2.imshow('original', img)
cv2.imshow("image", img_gray)
cv2.imshow('thresh img',thresh)
cv2.imshow('thresh adaptive', adaptive_thress)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# Edge Detection

# %%
image_path = os.path.join(path,'images','baller.jpg')
img = cv2.imread(image_path)
img = cv2.resize(img, (800,1400))
img_edgDe =  cv2.Canny(img, 100, 200)

# Dilate
img_edge_d = cv2.dilate(img_edgDe, np.ones((5,5),dtype=np.int8))

# erode 
img_edge_e = cv2.erode(img_edgDe, np.ones((1,1),dtype=np.int8))
cv2.imshow('original', img)
cv2.imshow("edg_image", img_edgDe)
cv2.imshow('dilated-img',img_edge_d)
cv2.imshow('dil-imge',img_edge_e)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Drawing in openCV

# %%
image_path = os.path.join(path,'images','whiteboard.png')
img = cv2.imread(image_path)

print(img.shape)
#line
cv2.line(img, (100,150),(300,450), (0,255,0),3)


#rectangle
cv2.rectangle(img, (200, 350), (450, 600), (255,0,0),3)

#circle
cv2.circle(img, (400, 200),100, (0,0,255),3)


#text 
cv2.putText(img, "Hey you!!", (400, 450), cv2.FONT_HERSHEY_SIMPLEX,2, (255,255,0),5)

cv2.imshow('original', img)
cv2.waitKey(0)
# Out:
# (671, 1000, 3)
# 0

# %% [markdown]
# # Contours

# %%
image_path = os.path.join(path,'images','birds.jpg')
img = cv2.imread(image_path)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_gray, 127, 255, cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(contours)
for cnt in contours:
    if cv2.contourArea(cnt) > 200:
        # cv2.drawContours(img, cnt,-1, (0,255,0), 4 )
        x1,y1,w,h = cv2.boundingRect(cnt)

        cv2.rectangle(img, (x1, y1), (x1 + w,y1+h), (0,255,0), 2)


cv2.imshow('original', img)
cv2.imshow('image gray', img_gray)
cv2.imshow('thresh', thresh)

cv2.waitKey(0)
# Out:
# (array([[[784, 838]],
#
#        [[781, 841]],
#
#        [[781, 843]],
#
#        [[780, 844]],
#
#        [[780, 849]],
#
#        [[779, 850]],
#
#        [[779, 853]],
#
#        [[793, 853]],
#
#        [[792, 852]],
#
#        [[792, 850]],
#
#        [[791, 849]],
#
#        [[791, 848]],
#
#        [[788, 845]],
#
#        [[788, 844]],
#
#        [[786, 842]],
#
#        [[786, 841]],
#
#        [[784, 839]]], dtype=int32), array([[[392, 814]],
#
#        [[391, 815]],
#
#        [[387, 815]],
#
#        [[386, 816]],
#
#        [[383, 816]],
#
#        [[382, 817]],
#
#        [[381, 817]],
#
#        [[380, 818]],
#
#        [[380, 819]],
#
#        [[379, 820]],
#
#        [[381, 822]],
#
#        [[381, 824]],
#
#        [[379, 826]],
#
#        [[375, 826]],
#
#        [[374, 827]],
#
#        [[373, 827]],
#
#        [[372, 828]],
#
#        [[371, 828]],
#
#        [[370, 829]],
#
#        [[373, 829]],
#
#        [[374, 830]],
#
#        [[376, 830]],
#
#        [[377, 831]],
#
#        [[379, 831]],
#
#        [[380, 832]],
#
#        [[382, 832]],
#
#        [[383, 833]],
#
#        [[393, 833]],
#
#        [[394, 832]],
#
#        [[396, 832]],
#
#        [[397, 831]],
#
#        [[404, 831]],
#
#        [[405, 832]],
#
#        [[407, 832]],
#
#        [[406, 832]],
#
#        [[405, 831]],
#
#        [[405, 830]],
#
#        [[407, 828]],
#
#        [[413, 828]],
#
#        [[413, 827]],
#
#        [[404, 827]],
#
#        [[403, 826]],
#
#        [[400, 826]],
#
#        [[399, 825]],
#
#        [[398, 825]],
#
#        [[396, 823]],
#
#        [[396, 822]],
#
#        [[397, 821]],
#
#        [[395, 819]],
#
#        [[395, 818]],
#
#        [[398, 815]],
#
#        [[399, 815]],
#
#        [[399, 814]]], dtype=int32), array([[[634, 812]],
#
#        [[634, 814]],
#
#        [[633, 815]],
#
#        [[633, 816]],
#
#        [[633, 815]],
#
#        [[634, 814]]], dtype=int32), array([[[635, 810]]], dtype=int32), array([[[636, 804]],
#
#        [[636, 805]]], dtype=int32), array([[[248, 800]],
#
#        [[248, 801]],
#
#        [[249, 802]],
#
#        [[249, 803]],
#
#        [[247, 805]],
#
#        [[246, 805]],
#
#        [[245, 806]],
#
#        [[244, 806]],
#
#        [[243, 807]],
#
#        [[242, 807]],
#
#        [[240, 809]],
#
#        [[242, 809]],
#
#        [[243, 810]],
#
#        [[245, 810]],
#
#        [[246, 811]],
#
#        [[250, 811]],
#
#        [[251, 812]],
#
#        [[252, 812]],
#
#        [[255, 815]],
#
#        [[255, 816]],
#
#        [[256, 816]],
#
#        [[258, 818]],
#
#        [[259, 818]],
#
#        [[260, 819]],
#
#        [[261, 819]],
#
#        [[262, 820]],
#
#        [[264, 820]],
#
#        [[265, 821]],
#
#        [[266, 821]],
#
#        [[267, 822]],
#
#        [[268, 822]],
#
#        [[269, 823]],
#
#        [[270, 822]],
#
#        [[271, 822]],
#
#        [[268, 819]],
#
#        [[268, 817]],
#
#        [[266, 815]],
#
#        [[266, 814]],
#
#        [[265, 813]],
#
#        [[269, 809]],
#
#        [[270, 809]],
#
#        [[271, 808]],
#
#        [[276, 808]],
#
#        [[277, 809]],
#
#        [[278, 809]],
#
#        [[278, 808]],
#
#        [[277, 807]],
#
#        [[271, 807]],
#
#        [[270, 806]],
#
#        [[266, 806]],
#
#        [[261, 801]],
#
#        [[258, 801]],
#
#        [[257, 800]]], dtype=int32), array([[[759, 799]],
#
#        [[759, 801]],
#
#        [[758, 802]],
#
#        [[758, 805]],
#
#        [[757, 806]],
#
#        [[757, 811]],
#
#        [[758, 812]],
#
#        [[758, 813]],
#
#        [[760, 815]],
#
#        [[760, 816]],
#
#        [[761, 817]],
#
#        [[758, 820]],
#
#        [[757, 820]],
#
#        [[756, 821]],
#
#        [[755, 821]],
#
#        [[754, 822]],
#
#        [[752, 822]],
#
#        [[752, 823]],
#
#        [[755, 823]],
#
#        [[756, 824]],
#
#        [[757, 824]],
#
#        [[758, 825]],
#
#        [[764, 825]],
#
#        [[765, 826]],
#
#        [[781, 826]],
#
#        [[781, 825]],
#
#        [[780, 824]],
#
#        [[780, 823]],
#
#        [[782, 821]],
#
#        [[783, 821]],
#
#        [[784, 820]],
#
#        [[789, 820]],
#
#        [[782, 820]],
#
#        [[781, 819]],
#
#        [[775, 819]],
#
#        [[773, 817]],
#
#        [[773, 815]],
#
#        [[769, 811]],
#
#        [[769, 809]],
#
#        [[768, 808]],
#
#        [[768, 806]],
#
#        [[764, 802]],
#
#        [[764, 801]],
#
#        [[763, 800]],
#
#        [[762, 800]],
#
#        [[761, 801]]], dtype=int32), array([[[848, 794]],
#
#        [[847, 795]],
#
#        [[845, 795]],
#
#        [[844, 796]],
#
#        [[841, 796]],
#
#        [[840, 797]],
#
#        [[838, 797]],
#
#        [[837, 798]],
#
#        [[839, 798]],
#
#        [[840, 799]],
#
#        [[841, 799]],
#
#        [[842, 800]],
#
#        [[845, 800]],
#
#        [[846, 801]],
#
#        [[848, 801]],
#
#        [[850, 803]],
#
#        [[850, 804]],
#
#        [[851, 805]],
#
#        [[851, 806]],
#
#        [[852, 807]],
#
#        [[852, 808]],
#
#        [[853, 809]],
#
#        [[853, 810]],
#
#        [[856, 813]],
#
#        [[856, 814]],
#
#        [[858, 816]],
#
#        [[859, 816]],
#
#        [[860, 817]],
#
#        [[862, 817]],
#
#        [[863, 816]],
#
#        [[864, 816]],
#
#        [[865, 817]],
#
#        [[865, 818]],
#
#        [[866, 818]],
#
#        [[866, 817]],
#
#        [[865, 816]],
#
#        [[865, 814]],
#
#        [[866, 813]],
#
#        [[865, 812]],
#
#        [[865, 808]],
#
#        [[864, 807]],
#
#        [[864, 804]],
#
#        [[863, 803]],
#
#        [[864, 802]],
#
#        [[864, 801]],
#
#        [[865, 800]],
#
#        [[866, 800]],
#
#        [[867, 799]],
#
#        [[868, 799]],
#
#        [[869, 798]],
#
#        [[876, 798]],
#
#        [[876, 797]],
#
#        [[865, 797]],
#
#        [[864, 796]],
#
#        [[861, 796]],
#
#        [[860, 795]],
#
#        [[853, 795]],
#
#        [[852, 794]]], dtype=int32), array([[[863, 812]],
#
#        [[864, 811]],
#
#        [[865, 812]],
#
#        [[865, 813]],
#
#        [[864, 814]],
#
#        [[863, 813]]], dtype=int32), array([[[1033,  789]],
#
#        [[1032,  790]],
#
#        [[1031,  790]],
#
#        [[1030,  791]],
#
#        [[1029,  791]],
#
#        [[1027,  793]],
#
#        [[1027,  794]],
#
#        [[1026,  795]],
#
#        [[1026,  796]],
#
#        [[1028,  798]],
#
#        [[1028,  799]],
#
#        [[1026,  801]],
#
#        [[1023,  801]],
#
#        [[1022,  802]],
#
#        [[1020,  802]],
#
#        [[1021,  803]],
#
#        [[1022,  803]],
#
#        [[1023,  804]],
#
#        [[1024,  804]],
#
#        [[1025,  805]],
#
#        [[1026,  805]],
#
#        [[1027,  806]],
#
#        [[1028,  806]],
#
#        [[1031,  809]],
#
#        [[1031,  810]],
#
#        [[1032,  811]],
#
#        [[1032,  812]],
#
#        [[1036,  816]],
#
#        [[1036,  817]],
#
#        [[1039,  820]],
#
#        [[1042,  820]],
#
#        [[1045,  823]],
#
#        [[1045,  816]],
#
#        [[1044,  815]],
#
#        [[1044,  812]],
#
#        [[1043,  811]],
#
#        [[1043,  807]],
#
#        [[1046,  804]],
#
#        [[1048,  804]],
#
#        [[1049,  803]],
#
#        [[1051,  803]],
#
#        [[1052,  802]],
#
#        [[1057,  802]],
#
#        [[1057,  801]],
#
#        [[1056,  802]],
#
#        [[1052,  802]],
#
#        [[1051,  801]],
#
#        [[1047,  801]],
#
#        [[1046,  800]],
#
#        [[1044,  800]],
#
#        [[1038,  794]],
#
#        [[1038,  793]],
#
#        [[1034,  789]]], dtype=int32), array([[[620, 784]],
#
#        [[619, 785]],
#
#        [[616, 785]],
#
#        [[615, 786]],
#
#        [[613, 786]],
#
#        [[612, 787]],
#
#        [[611, 787]],
#
#        [[612, 787]],
#
#        [[613, 788]],
#
#        [[615, 788]],
#
#        [[616, 789]],
#
#        [[617, 789]],
#
#        [[618, 790]],
#
#        [[620, 790]],
#
#        [[623, 793]],
#
#        [[623, 794]],
#
#        [[622, 795]],
#
#        [[622, 796]],
#
#        [[623, 797]],
#
#        [[623, 798]],
#
#        [[624, 799]],
#
#        [[624, 802]],
#
#        [[625, 803]],
#
#        [[625, 804]],
#
#        [[626, 805]],
#
#        [[626, 807]],
#
#        [[627, 808]],
#
#        [[627, 809]],
#
#        [[630, 812]],
#
#        [[630, 813]],
#
#        [[632, 813]],
#
#        [[632, 809]],
#
#        [[633, 808]],
#
#        [[632, 807]],
#
#        [[633, 806]],
#
#        [[633, 803]],
#
#        [[635, 801]],
#
#        [[636, 802]],
#
#        [[636, 796]],
#
#        [[634, 794]],
#
#        [[637, 791]],
#
#        [[638, 791]],
#
#        [[639, 790]],
#
#        [[642, 790]],
#
#        [[643, 789]],
#
#        [[649, 789]],
#
#        [[649, 788]],
#
#        [[642, 788]],
#
#        [[641, 787]],
#
#        [[638, 787]],
#
#        [[636, 785]],
#
#        [[631, 785]],
#
#        [[630, 784]]], dtype=int32), array([[[116, 764]],
#
#        [[115, 765]],
#
#        [[115, 766]],
#
#        [[114, 767]],
#
#        [[114, 768]],
#
#        [[115, 768]],
#
#        [[115, 766]],
#
#        [[116, 765]]], dtype=int32), array([[[116, 762]],
#
#        [[117, 762]]], dtype=int32), array([[[816, 745]],
#
#        [[815, 746]],
#
#        [[814, 746]],
#
#        [[813, 747]],
#
#        [[812, 747]],
#
#        [[811, 748]],
#
#        [[810, 748]],
#
#        [[809, 749]],
#
#        [[808, 749]],
#
#        [[807, 750]],
#
#        [[806, 750]],
#
#        [[808, 750]],
#
#        [[809, 751]],
#
#        [[811, 751]],
#
#        [[812, 752]],
#
#        [[813, 752]],
#
#        [[814, 753]],
#
#        [[817, 753]],
#
#        [[825, 761]],
#
#        [[827, 761]],
#
#        [[828, 762]],
#
#        [[829, 762]],
#
#        [[831, 764]],
#
#        [[833, 764]],
#
#        [[834, 765]],
#
#        [[836, 765]],
#
#        [[837, 766]],
#
#        [[839, 766]],
#
#        [[840, 765]],
#
#        [[839, 764]],
#
#        [[839, 762]],
#
#        [[838, 761]],
#
#        [[838, 759]],
#
#        [[837, 758]],
#
#        [[837, 757]],
#
#        [[835, 755]],
#
#        [[835, 753]],
#
#        [[837, 751]],
#
#        [[838, 751]],
#
#        [[839, 750]],
#
#        [[840, 750]],
#
#        [[841, 749]],
#
#        [[847, 749]],
#
#        [[847, 748]],
#
#        [[836, 748]],
#
#        [[835, 747]],
#
#        [[832, 747]],
#
#        [[830, 745]],
#
#        [[827, 745]],
#
#        [[826, 746]],
#
#        [[825, 745]]], dtype=int32), array([[[298, 740]],
#
#        [[298, 741]]], dtype=int32), array([[[100, 732]],
#
#        [[100, 734]],
#
#        [[ 99, 735]],
#
#        [[ 98, 735]],
#
#        [[ 97, 736]],
#
#        [[ 96, 736]],
#
#        [[ 94, 738]],
#
#        [[ 93, 738]],
#
#        [[ 94, 738]],
#
#        [[ 95, 739]],
#
#        [[ 96, 739]],
#
#        [[ 97, 740]],
#
#        [[ 99, 740]],
#
#        [[100, 741]],
#
#        [[103, 741]],
#
#        [[105, 743]],
#
#        [[105, 749]],
#
#        [[106, 750]],
#
#        [[106, 754]],
#
#        [[107, 755]],
#
#        [[107, 756]],
#
#        [[108, 757]],
#
#        [[108, 758]],
#
#        [[109, 759]],
#
#        [[109, 762]],
#
#        [[111, 764]],
#
#        [[112, 764]],
#
#        [[113, 765]],
#
#        [[113, 763]],
#
#        [[112, 762]],
#
#        [[112, 761]],
#
#        [[111, 760]],
#
#        [[112, 759]],
#
#        [[113, 759]],
#
#        [[112, 758]],
#
#        [[112, 757]],
#
#        [[113, 756]],
#
#        [[114, 756]],
#
#        [[114, 755]],
#
#        [[115, 754]],
#
#        [[116, 754]],
#
#        [[118, 756]],
#
#        [[119, 756]],
#
#        [[119, 755]],
#
#        [[118, 754]],
#
#        [[119, 753]],
#
#        [[119, 752]],
#
#        [[118, 752]],
#
#        [[117, 751]],
#
#        [[118, 750]],
#
#        [[119, 750]],
#
#        [[119, 749]],
#
#        [[117, 747]],
#
#        [[117, 746]],
#
#        [[119, 744]],
#
#        [[119, 740]],
#
#        [[120, 739]],
#
#        [[121, 739]],
#
#        [[122, 738]],
#
#        [[125, 738]],
#
#        [[126, 737]],
#
#        [[127, 737]],
#
#        [[128, 738]],
#
#        [[132, 738]],
#
#        [[132, 736]],
#
#        [[131, 735]],
#
#        [[131, 734]],
#
#        [[128, 734]],
#
#        [[127, 735]],
#
#        [[122, 735]],
#
#        [[121, 734]],
#
#        [[119, 734]],
#
#        [[118, 733]],
#
#        [[113, 733]],
#
#        [[112, 732]]], dtype=int32), array([[[115, 753]],
#
#        [[116, 752]],
#
#        [[117, 752]],
#
#        [[118, 753]],
#
#        [[117, 754]],
#
#        [[116, 754]]], dtype=int32), array([[[403, 724]],
#
#        [[403, 725]],
#
#        [[400, 728]],
#
#        [[399, 728]],
#
#        [[398, 729]],
#
#        [[398, 730]],
#
#        [[397, 731]],
#
#        [[397, 733]],
#
#        [[396, 734]],
#
#        [[396, 737]],
#
#        [[395, 738]],
#
#        [[395, 742]],
#
#        [[394, 743]],
#
#        [[394, 745]],
#
#        [[395, 746]],
#
#        [[395, 748]],
#
#        [[396, 749]],
#
#        [[396, 754]],
#
#        [[395, 755]],
#
#        [[394, 755]],
#
#        [[393, 756]],
#
#        [[391, 756]],
#
#        [[390, 757]],
#
#        [[389, 757]],
#
#        [[388, 758]],
#
#        [[387, 758]],
#
#        [[388, 759]],
#
#        [[390, 759]],
#
#        [[391, 760]],
#
#        [[393, 760]],
#
#        [[394, 761]],
#
#        [[397, 761]],
#
#        [[398, 762]],
#
#        [[413, 762]],
#
#        [[414, 761]],
#
#        [[418, 761]],
#
#        [[419, 760]],
#
#        [[421, 760]],
#
#        [[422, 759]],
#
#        [[426, 759]],
#
#        [[425, 758]],
#
#        [[417, 758]],
#
#        [[416, 757]],
#
#        [[414, 757]],
#
#        [[413, 756]],
#
#        [[412, 756]],
#
#        [[411, 755]],
#
#        [[410, 755]],
#
#        [[409, 754]],
#
#        [[409, 751]],
#
#        [[407, 749]],
#
#        [[407, 747]],
#
#        [[408, 746]],
#
#        [[408, 744]],
#
#        [[407, 743]],
#
#        [[407, 734]],
#
#        [[406, 733]],
#
#        [[406, 730]],
#
#        [[405, 729]],
#
#        [[405, 726]],
#
#        [[404, 725]],
#
#        [[404, 724]]], dtype=int32), array([[[404, 731]],
#
#        [[405, 730]],
#
#        [[406, 731]],
#
#        [[406, 732]],
#
#        [[405, 733]],
#
#        [[404, 732]]], dtype=int32), array([[[550, 723]],
#
#        [[550, 725]],
#
#        [[549, 726]],
#
#        [[549, 729]],
#
#        [[550, 730]],
#
#        [[551, 730]],
#
#        [[554, 733]],
#
#        [[554, 734]],
#
#        [[553, 735]],
#
#        [[552, 735]],
#
#        [[551, 736]],
#
#        [[549, 736]],
#
#        [[548, 737]],
#
#        [[547, 737]],
#
#        [[548, 737]],
#
#        [[549, 738]],
#
#        [[550, 738]],
#
#        [[551, 739]],
#
#        [[552, 739]],
#
#        [[553, 740]],
#
#        [[554, 740]],
#
#        [[555, 741]],
#
#        [[557, 741]],
#
#        [[559, 743]],
#
#        [[559, 747]],
#
#        [[560, 748]],
#
#        [[560, 750]],
#
#        [[561, 751]],
#
#        [[561, 752]],
#
#        [[562, 753]],
#
#        [[562, 754]],
#
#        [[563, 755]],
#
#        [[563, 756]],
#
#        [[564, 757]],
#
#        [[564, 758]],
#
#        [[565, 759]],
#
#        [[565, 760]],
#
#        [[566, 761]],
#
#        [[566, 762]],
#
#        [[568, 764]],
#
#        [[571, 764]],
#
#        [[572, 765]],
#
#        [[572, 766]],
#
#        [[573, 766]],
#
#        [[573, 759]],
#
#        [[572, 759]],
#
#        [[571, 758]],
#
#        [[571, 757]],
#
#        [[572, 756]],
#
#        [[573, 757]],
#
#        [[574, 757]],
#
#        [[574, 756]],
#
#        [[572, 756]],
#
#        [[570, 754]],
#
#        [[571, 753]],
#
#        [[572, 753]],
#
#        [[573, 754]],
#
#        [[574, 754]],
#
#        [[574, 751]],
#
#        [[573, 750]],
#
#        [[573, 746]],
#
#        [[572, 745]],
#
#        [[572, 744]],
#
#        [[571, 743]],
#
#        [[572, 742]],
#
#        [[572, 741]],
#
#        [[575, 738]],
#
#        [[576, 738]],
#
#        [[577, 737]],
#
#        [[584, 737]],
#
#        [[583, 736]],
#
#        [[583, 734]],
#
#        [[580, 734]],
#
#        [[579, 735]],
#
#        [[574, 735]],
#
#        [[573, 734]],
#
#        [[571, 734]],
#
#        [[569, 732]],
#
#        [[568, 732]],
#
#        [[567, 731]],
#
#        [[566, 731]],
#
#        [[564, 729]],
#
#        [[563, 729]],
#
#        [[560, 726]],
#
#        [[559, 726]],
#
#        [[558, 725]],
#
#        [[556, 725]],
#
#        [[555, 724]],
#
#        [[554, 724]],
#
#        [[553, 723]]], dtype=int32), array([[[570, 762]],
#
#        [[571, 761]],
#
#        [[572, 761]],
#
#        [[573, 762]],
#
#        [[572, 763]],
#
#        [[571, 763]]], dtype=int32), array([[[571, 760]],
#
#        [[572, 759]],
#
#        [[573, 760]],
#
#        [[572, 761]]], dtype=int32), array([[[571, 752]],
#
#        [[572, 751]],
#
#        [[573, 751]],
#
#        [[574, 752]],
#
#        [[573, 753]],
#
#        [[572, 753]]], dtype=int32), array([[[279, 720]],
#
#        [[278, 721]],
#
#        [[276, 721]],
#
#        [[275, 722]],
#
#        [[273, 722]],
#
#        [[272, 723]],
#
#        [[271, 723]],
#
#        [[273, 723]],
#
#        [[275, 725]],
#
#        [[276, 725]],
#
#        [[278, 727]],
#
#        [[281, 727]],
#
#        [[282, 728]],
#
#        [[283, 728]],
#
#        [[284, 729]],
#
#        [[284, 736]],
#
#        [[285, 737]],
#
#        [[285, 739]],
#
#        [[286, 740]],
#
#        [[286, 741]],
#
#        [[287, 742]],
#
#        [[287, 746]],
#
#        [[292, 751]],
#
#        [[294, 751]],
#
#        [[296, 753]],
#
#        [[296, 749]],
#
#        [[297, 748]],
#
#        [[297, 745]],
#
#        [[298, 744]],
#
#        [[298, 743]],
#
#        [[296, 743]],
#
#        [[294, 741]],
#
#        [[295, 740]],
#
#        [[296, 740]],
#
#        [[295, 739]],
#
#        [[295, 738]],
#
#        [[296, 737]],
#
#        [[298, 737]],
#
#        [[298, 728]],
#
#        [[300, 726]],
#
#        [[303, 726]],
#
#        [[304, 725]],
#
#        [[305, 726]],
#
#        [[310, 726]],
#
#        [[311, 727]],
#
#        [[311, 723]],
#
#        [[301, 723]],
#
#        [[300, 722]],
#
#        [[298, 722]],
#
#        [[297, 721]],
#
#        [[295, 721]],
#
#        [[294, 720]]], dtype=int32), array([[[294, 750]],
#
#        [[295, 749]],
#
#        [[296, 750]],
#
#        [[295, 751]]], dtype=int32), array([[[294, 747]],
#
#        [[295, 746]],
#
#        [[296, 747]],
#
#        [[295, 748]]], dtype=int32), array([[[294, 744]],
#
#        [[295, 743]],
#
#        [[296, 743]],
#
#        [[297, 744]],
#
#        [[297, 746]],
#
#        [[296, 747]],
#
#        [[295, 746]],
#
#        [[295, 745]]], dtype=int32), array([[[140, 695]],
#
#        [[141, 696]],
#
#        [[142, 696]],
#
#        [[141, 696]]], dtype=int32), array([[[142, 693]]], dtype=int32), array([[[1229,  685]],
#
#        [[1229,  687]],
#
#        [[1228,  688]],
#
#        [[1228,  689]],
#
#        [[1227,  690]],
#
#        [[1227,  691]],
#
#        [[1226,  692]],
#
#        [[1226,  694]],
#
#        [[1225,  695]],
#
#        [[1225,  697]],
#
#        [[1224,  698]],
#
#        [[1224,  704]],
#
#        [[1223,  705]],
#
#        [[1224,  706]],
#
#        [[1224,  707]],
#
#        [[1225,  708]],
#
#        [[1225,  710]],
#
#        [[1226,  711]],
#
#        [[1226,  713]],
#
#        [[1225,  714]],
#
#        [[1225,  715]],
#
#        [[1224,  716]],
#
#        [[1223,  716]],
#
#        [[1222,  717]],
#
#        [[1219,  717]],
#
#        [[1218,  718]],
#
#        [[1217,  718]],
#
#        [[1218,  719]],
#
#        [[1220,  719]],
#
#        [[1221,  720]],
#
#        [[1222,  720]],
#
#        [[1223,  721]],
#
#        [[1226,  721]],
#
#        [[1227,  722]],
#
#        [[1244,  722]],
#
#        [[1245,  721]],
#
#        [[1246,  721]],
#
#        [[1246,  720]],
#
#        [[1248,  718]],
#
#        [[1249,  718]],
#
#        [[1250,  717]],
#
#        [[1256,  717]],
#
#        [[1256,  716]],
#
#        [[1254,  714]],
#
#        [[1253,  714]],
#
#        [[1252,  715]],
#
#        [[1240,  715]],
#
#        [[1239,  714]],
#
#        [[1239,  709]],
#
#        [[1238,  708]],
#
#        [[1238,  706]],
#
#        [[1237,  705]],
#
#        [[1237,  702]],
#
#        [[1236,  701]],
#
#        [[1236,  696]],
#
#        [[1235,  695]],
#
#        [[1235,  693]],
#
#        [[1234,  692]],
#
#        [[1234,  691]],
#
#        [[1233,  690]],
#
#        [[1233,  687]],
#
#        [[1232,  687]],
#
#        [[1231,  688]],
#
#        [[1230,  687]],
#
#        [[1230,  686]]], dtype=int32), array([[[1233,  693]],
#
#        [[1234,  692]],
#
#        [[1235,  693]],
#
#        [[1234,  694]]], dtype=int32), array([[[1232,  691]],
#
#        [[1233,  690]],
#
#        [[1234,  691]],
#
#        [[1233,  692]]], dtype=int32), array([[[400, 683]],
#
#        [[399, 684]],
#
#        [[397, 684]],
#
#        [[396, 685]],
#
#        [[395, 685]],
#
#        [[394, 686]],
#
#        [[392, 686]],
#
#        [[391, 687]],
#
#        [[390, 687]],
#
#        [[387, 690]],
#
#        [[387, 692]],
#
#        [[388, 693]],
#
#        [[388, 695]],
#
#        [[387, 696]],
#
#        [[385, 696]],
#
#        [[384, 697]],
#
#        [[382, 697]],
#
#        [[381, 698]],
#
#        [[380, 698]],
#
#        [[381, 698]],
#
#        [[382, 699]],
#
#        [[383, 699]],
#
#        [[385, 701]],
#
#        [[387, 701]],
#
#        [[388, 702]],
#
#        [[392, 702]],
#
#        [[393, 703]],
#
#        [[398, 703]],
#
#        [[399, 702]],
#
#        [[402, 702]],
#
#        [[403, 701]],
#
#        [[406, 701]],
#
#        [[407, 700]],
#
#        [[409, 700]],
#
#        [[410, 699]],
#
#        [[416, 699]],
#
#        [[416, 698]],
#
#        [[405, 698]],
#
#        [[404, 697]],
#
#        [[403, 697]],
#
#        [[402, 696]],
#
#        [[402, 692]],
#
#        [[401, 691]],
#
#        [[401, 688]],
#
#        [[402, 687]],
#
#        [[402, 686]],
#
#        [[405, 683]]], dtype=int32), array([[[ 17, 670]],
#
#        [[ 16, 671]],
#
#        [[ 15, 671]],
#
#        [[ 15, 672]],
#
#        [[ 16, 673]],
#
#        [[ 16, 675]],
#
#        [[ 15, 676]],
#
#        [[ 15, 678]],
#
#        [[ 16, 679]],
#
#        [[ 16, 680]],
#
#        [[ 22, 686]],
#
#        [[ 22, 688]],
#
#        [[ 23, 689]],
#
#        [[ 21, 691]],
#
#        [[ 18, 691]],
#
#        [[ 17, 692]],
#
#        [[ 16, 692]],
#
#        [[ 15, 693]],
#
#        [[ 14, 693]],
#
#        [[ 15, 693]],
#
#        [[ 16, 694]],
#
#        [[ 17, 694]],
#
#        [[ 18, 695]],
#
#        [[ 19, 695]],
#
#        [[ 20, 696]],
#
#        [[ 21, 696]],
#
#        [[ 22, 697]],
#
#        [[ 25, 697]],
#
#        [[ 27, 699]],
#
#        [[ 27, 705]],
#
#        [[ 28, 706]],
#
#        [[ 28, 709]],
#
#        [[ 29, 710]],
#
#        [[ 29, 712]],
#
#        [[ 30, 713]],
#
#        [[ 30, 716]],
#
#        [[ 31, 717]],
#
#        [[ 31, 718]],
#
#        [[ 35, 722]],
#
#        [[ 36, 722]],
#
#        [[ 38, 720]],
#
#        [[ 38, 719]],
#
#        [[ 39, 718]],
#
#        [[ 39, 717]],
#
#        [[ 40, 716]],
#
#        [[ 40, 715]],
#
#        [[ 41, 714]],
#
#        [[ 41, 712]],
#
#        [[ 42, 711]],
#
#        [[ 42, 704]],
#
#        [[ 41, 703]],
#
#        [[ 41, 702]],
#
#        [[ 40, 701]],
#
#        [[ 40, 699]],
#
#        [[ 41, 698]],
#
#        [[ 41, 697]],
#
#        [[ 44, 694]],
#
#        [[ 54, 694]],
#
#        [[ 53, 693]],
#
#        [[ 53, 692]],
#
#        [[ 43, 692]],
#
#        [[ 42, 691]],
#
#        [[ 39, 691]],
#
#        [[ 36, 688]],
#
#        [[ 36, 686]],
#
#        [[ 33, 683]],
#
#        [[ 33, 682]],
#
#        [[ 32, 681]],
#
#        [[ 32, 680]],
#
#        [[ 27, 675]],
#
#        [[ 26, 675]],
#
#        [[ 24, 673]],
#
#        [[ 23, 673]],
#
#        [[ 22, 672]],
#
#        [[ 20, 672]],
#
#        [[ 18, 670]]], dtype=int32), array([[[ 38, 714]],
#
#        [[ 39, 713]],
#
#        [[ 40, 714]],
#
#        [[ 39, 715]]], dtype=int32), array([[[ 39, 712]],
#
#        [[ 40, 711]],
#
#        [[ 41, 712]],
#
#        [[ 40, 713]]], dtype=int32), array([[[877, 665]],
#
#        [[875, 667]],
#
#        [[874, 667]],
#
#        [[872, 669]],
#
#        [[871, 669]],
#
#        [[869, 671]],
#
#        [[869, 672]],
#
#        [[866, 675]],
#
#        [[866, 676]],
#
#        [[865, 677]],
#
#        [[865, 682]],
#
#        [[867, 684]],
#
#        [[867, 686]],
#
#        [[865, 688]],
#
#        [[864, 688]],
#
#        [[863, 689]],
#
#        [[861, 689]],
#
#        [[860, 690]],
#
#        [[859, 690]],
#
#        [[858, 691]],
#
#        [[861, 691]],
#
#        [[862, 692]],
#
#        [[863, 692]],
#
#        [[864, 693]],
#
#        [[865, 693]],
#
#        [[866, 694]],
#
#        [[877, 694]],
#
#        [[878, 693]],
#
#        [[880, 693]],
#
#        [[881, 692]],
#
#        [[883, 692]],
#
#        [[884, 691]],
#
#        [[886, 691]],
#
#        [[887, 690]],
#
#        [[888, 690]],
#
#        [[889, 689]],
#
#        [[896, 689]],
#
#        [[896, 688]],
#
#        [[895, 687]],
#
#        [[894, 687]],
#
#        [[893, 688]],
#
#        [[882, 688]],
#
#        [[880, 686]],
#
#        [[880, 682]],
#
#        [[878, 680]],
#
#        [[878, 671]],
#
#        [[877, 670]]], dtype=int32), array([[[239, 659]],
#
#        [[239, 661]],
#
#        [[237, 663]],
#
#        [[232, 663]],
#
#        [[231, 664]],
#
#        [[230, 664]],
#
#        [[230, 665]],
#
#        [[232, 665]],
#
#        [[233, 666]],
#
#        [[234, 666]],
#
#        [[235, 667]],
#
#        [[237, 667]],
#
#        [[238, 668]],
#
#        [[239, 668]],
#
#        [[244, 673]],
#
#        [[245, 673]],
#
#        [[246, 674]],
#
#        [[249, 674]],
#
#        [[250, 675]],
#
#        [[252, 675]],
#
#        [[253, 676]],
#
#        [[257, 676]],
#
#        [[258, 677]],
#
#        [[259, 677]],
#
#        [[259, 676]],
#
#        [[255, 672]],
#
#        [[255, 669]],
#
#        [[256, 668]],
#
#        [[257, 668]],
#
#        [[258, 667]],
#
#        [[262, 667]],
#
#        [[263, 668]],
#
#        [[265, 668]],
#
#        [[266, 669]],
#
#        [[266, 664]],
#
#        [[257, 664]],
#
#        [[254, 661]],
#
#        [[251, 661]],
#
#        [[250, 660]],
#
#        [[246, 660]],
#
#        [[245, 659]]], dtype=int32), array([[[484, 648]],
#
#        [[484, 649]]], dtype=int32), array([[[118, 648]],
#
#        [[117, 649]],
#
#        [[117, 651]],
#
#        [[115, 653]],
#
#        [[115, 654]],
#
#        [[116, 655]],
#
#        [[116, 657]],
#
#        [[117, 658]],
#
#        [[117, 659]],
#
#        [[118, 660]],
#
#        [[118, 661]],
#
#        [[120, 663]],
#
#        [[120, 664]],
#
#        [[123, 667]],
#
#        [[123, 669]],
#
#        [[122, 670]],
#
#        [[119, 670]],
#
#        [[118, 671]],
#
#        [[117, 671]],
#
#        [[115, 673]],
#
#        [[114, 673]],
#
#        [[115, 673]],
#
#        [[116, 674]],
#
#        [[118, 674]],
#
#        [[119, 675]],
#
#        [[120, 675]],
#
#        [[121, 676]],
#
#        [[122, 676]],
#
#        [[123, 677]],
#
#        [[125, 677]],
#
#        [[127, 679]],
#
#        [[127, 686]],
#
#        [[128, 687]],
#
#        [[128, 691]],
#
#        [[129, 692]],
#
#        [[129, 694]],
#
#        [[130, 695]],
#
#        [[130, 698]],
#
#        [[131, 699]],
#
#        [[131, 701]],
#
#        [[132, 702]],
#
#        [[132, 703]],
#
#        [[133, 703]],
#
#        [[136, 706]],
#
#        [[137, 706]],
#
#        [[137, 705]],
#
#        [[138, 704]],
#
#        [[138, 703]],
#
#        [[139, 702]],
#
#        [[139, 701]],
#
#        [[138, 701]],
#
#        [[136, 699]],
#
#        [[136, 698]],
#
#        [[135, 697]],
#
#        [[136, 696]],
#
#        [[137, 696]],
#
#        [[140, 699]],
#
#        [[140, 698]],
#
#        [[139, 698]],
#
#        [[136, 695]],
#
#        [[137, 694]],
#
#        [[138, 694]],
#
#        [[137, 693]],
#
#        [[138, 692]],
#
#        [[140, 692]],
#
#        [[139, 692]],
#
#        [[138, 691]],
#
#        [[138, 690]],
#
#        [[139, 689]],
#
#        [[141, 689]],
#
#        [[142, 690]],
#
#        [[142, 683]],
#
#        [[140, 681]],
#
#        [[140, 678]],
#
#        [[142, 676]],
#
#        [[143, 676]],
#
#        [[144, 675]],
#
#        [[147, 675]],
#
#        [[148, 674]],
#
#        [[150, 674]],
#
#        [[151, 675]],
#
#        [[154, 675]],
#
#        [[153, 674]],
#
#        [[153, 673]],
#
#        [[152, 672]],
#
#        [[151, 672]],
#
#        [[150, 673]],
#
#        [[146, 673]],
#
#        [[145, 672]],
#
#        [[143, 672]],
#
#        [[142, 671]],
#
#        [[141, 671]],
#
#        [[140, 670]],
#
#        [[139, 670]],
#
#        [[137, 668]],
#
#        [[137, 667]],
#
#        [[136, 666]],
#
#        [[136, 665]],
#
#        [[135, 664]],
#
#        [[135, 663]],
#
#        [[134, 662]],
#
#        [[134, 661]],
#
#        [[132, 659]],
#
#        [[132, 658]],
#
#        [[128, 654]],
#
#        [[127, 654]],
#
#        [[126, 653]],
#
#        [[125, 653]],
#
#        [[123, 651]],
#
#        [[122, 651]],
#
#        [[120, 649]],
#
#        [[119, 649]]], dtype=int32), array([[[135, 704]],
#
#        [[136, 703]],
#
#        [[137, 704]],
#
#        [[136, 705]]], dtype=int32), array([[[134, 700]],
#
#        [[135, 699]],
#
#        [[136, 699]],
#
#        [[138, 701]],
#
#        [[138, 702]],
#
#        [[137, 703]]], dtype=int32), array([[[482, 639]],
#
#        [[482, 640]],
#
#        [[479, 643]],
#
#        [[477, 643]],
#
#        [[476, 644]],
#
#        [[476, 645]],
#
#        [[475, 646]],
#
#        [[475, 647]],
#
#        [[474, 648]],
#
#        [[474, 649]],
#
#        [[473, 650]],
#
#        [[473, 652]],
#
#        [[472, 653]],
#
#        [[472, 654]],
#
#        [[471, 655]],
#
#        [[471, 657]],
#
#        [[470, 658]],
#
#        [[470, 663]],
#
#        [[469, 664]],
#
#        [[469, 665]],
#
#        [[470, 666]],
#
#        [[470, 668]],
#
#        [[471, 669]],
#
#        [[471, 672]],
#
#        [[470, 673]],
#
#        [[470, 674]],
#
#        [[467, 677]],
#
#        [[465, 677]],
#
#        [[464, 678]],
#
#        [[463, 678]],
#
#        [[462, 679]],
#
#        [[461, 679]],
#
#        [[460, 680]],
#
#        [[459, 680]],
#
#        [[461, 680]],
#
#        [[462, 681]],
#
#        [[464, 681]],
#
#        [[465, 682]],
#
#        [[467, 682]],
#
#        [[468, 683]],
#
#        [[474, 683]],
#
#        [[475, 684]],
#
#        [[476, 684]],
#
#        [[477, 685]],
#
#        [[478, 685]],
#
#        [[479, 686]],
#
#        [[481, 686]],
#
#        [[482, 687]],
#
#        [[484, 687]],
#
#        [[485, 688]],
#
#        [[489, 688]],
#
#        [[490, 687]],
#
#        [[496, 687]],
#
#        [[496, 686]],
#
#        [[495, 685]],
#
#        [[494, 685]],
#
#        [[491, 682]],
#
#        [[493, 680]],
#
#        [[499, 680]],
#
#        [[500, 681]],
#
#        [[501, 681]],
#
#        [[502, 680]],
#
#        [[502, 679]],
#
#        [[500, 677]],
#
#        [[500, 676]],
#
#        [[501, 675]],
#
#        [[501, 674]],
#
#        [[499, 672]],
#
#        [[498, 672]],
#
#        [[497, 673]],
#
#        [[496, 673]],
#
#        [[495, 674]],
#
#        [[493, 674]],
#
#        [[492, 675]],
#
#        [[488, 675]],
#
#        [[485, 672]],
#
#        [[485, 671]],
#
#        [[484, 670]],
#
#        [[485, 669]],
#
#        [[483, 667]],
#
#        [[483, 666]],
#
#        [[484, 665]],
#
#        [[485, 666]],
#
#        [[486, 666]],
#
#        [[485, 666]],
#
#        [[484, 665]],
#
#        [[483, 665]],
#
#        [[482, 664]],
#
#        [[483, 663]],
#
#        [[485, 663]],
#
#        [[484, 662]],
#
#        [[485, 661]],
#
#        [[485, 657]],
#
#        [[483, 659]],
#
#        [[482, 659]],
#
#        [[481, 658]],
#
#        [[481, 657]],
#
#        [[482, 656]],
#
#        [[483, 656]],
#
#        [[484, 655]],
#
#        [[485, 655]],
#
#        [[485, 652]],
#
#        [[484, 652]],
#
#        [[483, 653]],
#
#        [[482, 653]],
#
#        [[481, 654]],
#
#        [[480, 654]],
#
#        [[479, 653]],
#
#        [[481, 651]],
#
#        [[480, 652]],
#
#        [[479, 651]],
#
#        [[479, 650]],
#
#        [[481, 648]],
#
#        [[481, 647]],
#
#        [[482, 646]],
#
#        [[484, 646]],
#
#        [[483, 645]],
#
#        [[483, 639]]], dtype=int32), array([[[483, 653]],
#
#        [[484, 652]],
#
#        [[485, 653]],
#
#        [[485, 654]],
#
#        [[483, 656]],
#
#        [[482, 656]],
#
#        [[481, 657]],
#
#        [[480, 656]],
#
#        [[480, 655]],
#
#        [[482, 653]]], dtype=int32), array([[[482, 643]],
#
#        [[483, 644]],
#
#        [[483, 645]],
#
#        [[481, 647]],
#
#        [[480, 646]],
#
#        [[480, 645]]], dtype=int32), array([[[416, 635]],
#
#        [[415, 636]],
#
#        [[411, 636]],
#
#        [[410, 637]],
#
#        [[407, 637]],
#
#        [[406, 638]],
#
#        [[403, 638]],
#
#        [[402, 639]],
#
#        [[401, 639]],
#
#        [[401, 641]],
#
#        [[402, 642]],
#
#        [[400, 644]],
#
#        [[399, 644]],
#
#        [[398, 645]],
#
#        [[395, 645]],
#
#        [[394, 646]],
#
#        [[393, 646]],
#
#        [[393, 647]],
#
#        [[395, 647]],
#
#        [[396, 648]],
#
#        [[397, 648]],
#
#        [[398, 649]],
#
#        [[402, 649]],
#
#        [[403, 650]],
#
#        [[416, 650]],
#
#        [[417, 651]],
#
#        [[425, 651]],
#
#        [[424, 651]],
#
#        [[421, 648]],
#
#        [[421, 647]],
#
#        [[423, 645]],
#
#        [[425, 645]],
#
#        [[426, 644]],
#
#        [[432, 644]],
#
#        [[432, 643]],
#
#        [[427, 643]],
#
#        [[426, 644]],
#
#        [[424, 644]],
#
#        [[423, 643]],
#
#        [[422, 644]],
#
#        [[421, 643]],
#
#        [[420, 644]],
#
#        [[419, 643]],
#
#        [[418, 643]],
#
#        [[417, 642]],
#
#        [[417, 641]],
#
#        [[416, 640]],
#
#        [[416, 639]],
#
#        [[419, 636]],
#
#        [[419, 635]]], dtype=int32), array([[[634, 620]],
#
#        [[634, 622]],
#
#        [[633, 623]],
#
#        [[633, 624]],
#
#        [[632, 625]],
#
#        [[631, 625]],
#
#        [[630, 624]],
#
#        [[630, 622]],
#
#        [[630, 623]],
#
#        [[629, 624]],
#
#        [[629, 626]],
#
#        [[627, 628]],
#
#        [[627, 630]],
#
#        [[626, 631]],
#
#        [[626, 633]],
#
#        [[625, 634]],
#
#        [[625, 637]],
#
#        [[624, 638]],
#
#        [[624, 643]],
#
#        [[623, 644]],
#
#        [[623, 648]],
#
#        [[624, 649]],
#
#        [[624, 651]],
#
#        [[625, 652]],
#
#        [[625, 656]],
#
#        [[622, 659]],
#
#        [[620, 659]],
#
#        [[619, 660]],
#
#        [[618, 660]],
#
#        [[616, 662]],
#
#        [[619, 662]],
#
#        [[620, 663]],
#
#        [[621, 663]],
#
#        [[623, 665]],
#
#        [[624, 665]],
#
#        [[625, 666]],
#
#        [[630, 666]],
#
#        [[634, 670]],
#
#        [[635, 670]],
#
#        [[636, 671]],
#
#        [[637, 671]],
#
#        [[638, 672]],
#
#        [[640, 672]],
#
#        [[641, 673]],
#
#        [[642, 673]],
#
#        [[643, 674]],
#
#        [[646, 674]],
#
#        [[647, 675]],
#
#        [[652, 675]],
#
#        [[653, 674]],
#
#        [[657, 674]],
#
#        [[656, 674]],
#
#        [[651, 669]],
#
#        [[650, 669]],
#
#        [[647, 666]],
#
#        [[647, 665]],
#
#        [[645, 663]],
#
#        [[645, 662]],
#
#        [[646, 661]],
#
#        [[647, 661]],
#
#        [[648, 660]],
#
#        [[654, 660]],
#
#        [[654, 657]],
#
#        [[651, 657]],
#
#        [[650, 658]],
#
#        [[641, 658]],
#
#        [[639, 656]],
#
#        [[640, 655]],
#
#        [[640, 654]],
#
#        [[639, 653]],
#
#        [[639, 645]],
#
#        [[638, 644]],
#
#        [[638, 636]],
#
#        [[637, 635]],
#
#        [[638, 634]],
#
#        [[637, 633]],
#
#        [[637, 630]],
#
#        [[636, 629]],
#
#        [[636, 627]],
#
#        [[635, 626]],
#
#        [[635, 622]],
#
#        [[634, 621]]], dtype=int32), array([[[635, 636]],
#
#        [[636, 635]],
#
#        [[637, 635]],
#
#        [[638, 636]],
#
#        [[636, 638]],
#
#        [[635, 637]]], dtype=int32), array([[[634, 633]],
#
#        [[635, 632]],
#
#        [[636, 632]],
#
#        [[637, 633]],
#
#        [[635, 635]],
#
#        [[634, 634]]], dtype=int32), array([[[635, 629]],
#
#        [[636, 629]],
#
#        [[637, 630]],
#
#        [[635, 632]],
#
#        [[634, 632]],
#
#        [[633, 631]]], dtype=int32), array([[[633, 627]],
#
#        [[634, 626]],
#
#        [[635, 627]],
#
#        [[635, 628]],
#
#        [[634, 629]],
#
#        [[633, 628]]], dtype=int32), array([[[632, 625]],
#
#        [[633, 624]],
#
#        [[634, 625]],
#
#        [[633, 626]]], dtype=int32), array([[[1195,  618]],
#
#        [[1191,  622]],
#
#        [[1191,  623]],
#
#        [[1192,  624]],
#
#        [[1190,  626]],
#
#        [[1188,  626]],
#
#        [[1187,  627]],
#
#        [[1185,  627]],
#
#        [[1184,  628]],
#
#        [[1186,  628]],
#
#        [[1187,  629]],
#
#        [[1188,  629]],
#
#        [[1189,  630]],
#
#        [[1192,  630]],
#
#        [[1193,  631]],
#
#        [[1194,  631]],
#
#        [[1196,  633]],
#
#        [[1196,  637]],
#
#        [[1197,  638]],
#
#        [[1197,  640]],
#
#        [[1198,  641]],
#
#        [[1198,  642]],
#
#        [[1199,  643]],
#
#        [[1199,  644]],
#
#        [[1200,  645]],
#
#        [[1200,  646]],
#
#        [[1201,  647]],
#
#        [[1201,  649]],
#
#        [[1202,  650]],
#
#        [[1202,  651]],
#
#        [[1204,  653]],
#
#        [[1208,  653]],
#
#        [[1207,  652]],
#
#        [[1208,  651]],
#
#        [[1208,  650]],
#
#        [[1209,  649]],
#
#        [[1210,  649]],
#
#        [[1211,  650]],
#
#        [[1211,  651]],
#
#        [[1210,  652]],
#
#        [[1210,  656]],
#
#        [[1210,  653]],
#
#        [[1211,  652]],
#
#        [[1211,  646]],
#
#        [[1210,  645]],
#
#        [[1211,  644]],
#
#        [[1212,  644]],
#
#        [[1212,  643]],
#
#        [[1211,  642]],
#
#        [[1211,  632]],
#
#        [[1214,  629]],
#
#        [[1215,  629]],
#
#        [[1216,  628]],
#
#        [[1218,  628]],
#
#        [[1219,  627]],
#
#        [[1226,  627]],
#
#        [[1225,  626]],
#
#        [[1215,  626]],
#
#        [[1214,  625]],
#
#        [[1211,  625]],
#
#        [[1210,  624]],
#
#        [[1209,  624]],
#
#        [[1206,  621]],
#
#        [[1205,  621]],
#
#        [[1203,  619]],
#
#        [[1200,  619]],
#
#        [[1199,  618]]], dtype=int32), array([[[1209,  647]],
#
#        [[1210,  646]],
#
#        [[1211,  647]],
#
#        [[1211,  648]],
#
#        [[1210,  649]],
#
#        [[1209,  648]]], dtype=int32), array([[[225, 602]],
#
#        [[224, 603]],
#
#        [[221, 603]],
#
#        [[220, 604]],
#
#        [[217, 604]],
#
#        [[216, 605]],
#
#        [[215, 605]],
#
#        [[213, 607]],
#
#        [[212, 607]],
#
#        [[208, 611]],
#
#        [[208, 615]],
#
#        [[209, 616]],
#
#        [[209, 619]],
#
#        [[208, 620]],
#
#        [[207, 620]],
#
#        [[206, 621]],
#
#        [[203, 621]],
#
#        [[202, 622]],
#
#        [[201, 622]],
#
#        [[200, 623]],
#
#        [[199, 623]],
#
#        [[200, 623]],
#
#        [[201, 624]],
#
#        [[202, 624]],
#
#        [[203, 625]],
#
#        [[204, 625]],
#
#        [[205, 626]],
#
#        [[208, 626]],
#
#        [[209, 627]],
#
#        [[211, 627]],
#
#        [[212, 628]],
#
#        [[220, 628]],
#
#        [[221, 627]],
#
#        [[230, 627]],
#
#        [[231, 628]],
#
#        [[232, 628]],
#
#        [[231, 627]],
#
#        [[231, 626]],
#
#        [[233, 624]],
#
#        [[237, 624]],
#
#        [[238, 625]],
#
#        [[240, 625]],
#
#        [[240, 624]],
#
#        [[239, 623]],
#
#        [[239, 622]],
#
#        [[238, 621]],
#
#        [[236, 621]],
#
#        [[235, 622]],
#
#        [[228, 622]],
#
#        [[227, 621]],
#
#        [[225, 621]],
#
#        [[224, 620]],
#
#        [[224, 619]],
#
#        [[225, 618]],
#
#        [[225, 617]],
#
#        [[223, 615]],
#
#        [[223, 611]],
#
#        [[224, 610]],
#
#        [[224, 609]],
#
#        [[225, 608]],
#
#        [[225, 606]],
#
#        [[228, 603]],
#
#        [[228, 602]]], dtype=int32), array([[[280, 588]],
#
#        [[278, 590]],
#
#        [[278, 591]],
#
#        [[273, 596]],
#
#        [[273, 597]],
#
#        [[272, 598]],
#
#        [[272, 599]],
#
#        [[270, 601]],
#
#        [[270, 603]],
#
#        [[269, 604]],
#
#        [[269, 613]],
#
#        [[270, 614]],
#
#        [[270, 617]],
#
#        [[271, 618]],
#
#        [[271, 619]],
#
#        [[270, 620]],
#
#        [[270, 621]],
#
#        [[268, 623]],
#
#        [[264, 623]],
#
#        [[263, 624]],
#
#        [[262, 624]],
#
#        [[261, 625]],
#
#        [[260, 625]],
#
#        [[259, 626]],
#
#        [[262, 626]],
#
#        [[263, 627]],
#
#        [[264, 627]],
#
#        [[265, 628]],
#
#        [[266, 628]],
#
#        [[267, 629]],
#
#        [[268, 629]],
#
#        [[269, 630]],
#
#        [[279, 630]],
#
#        [[280, 631]],
#
#        [[287, 631]],
#
#        [[288, 630]],
#
#        [[293, 630]],
#
#        [[294, 629]],
#
#        [[293, 628]],
#
#        [[295, 626]],
#
#        [[301, 626]],
#
#        [[302, 627]],
#
#        [[304, 627]],
#
#        [[304, 625]],
#
#        [[303, 624]],
#
#        [[303, 622]],
#
#        [[299, 622]],
#
#        [[298, 623]],
#
#        [[289, 623]],
#
#        [[288, 622]],
#
#        [[287, 622]],
#
#        [[286, 621]],
#
#        [[286, 620]],
#
#        [[287, 619]],
#
#        [[287, 613]],
#
#        [[285, 611]],
#
#        [[285, 608]],
#
#        [[284, 607]],
#
#        [[285, 606]],
#
#        [[285, 603]],
#
#        [[284, 602]],
#
#        [[284, 599]],
#
#        [[282, 601]],
#
#        [[280, 601]],
#
#        [[279, 600]],
#
#        [[282, 597]],
#
#        [[283, 597]],
#
#        [[283, 596]],
#
#        [[282, 596]],
#
#        [[281, 597]],
#
#        [[280, 596]],
#
#        [[280, 595]],
#
#        [[281, 594]],
#
#        [[282, 594]],
#
#        [[282, 593]],
#
#        [[281, 592]],
#
#        [[281, 589]]], dtype=int32), array([[[283, 600]],
#
#        [[284, 601]],
#
#        [[284, 602]],
#
#        [[282, 604]],
#
#        [[281, 603]],
#
#        [[281, 602]]], dtype=int32), array([[[279, 597]],
#
#        [[280, 596]],
#
#        [[281, 597]],
#
#        [[280, 598]]], dtype=int32), array([[[381, 586]],
#
#        [[381, 587]],
#
#        [[379, 589]],
#
#        [[379, 590]],
#
#        [[378, 591]],
#
#        [[377, 591]],
#
#        [[376, 592]],
#
#        [[376, 594]],
#
#        [[375, 595]],
#
#        [[375, 597]],
#
#        [[374, 598]],
#
#        [[374, 600]],
#
#        [[373, 601]],
#
#        [[373, 610]],
#
#        [[374, 611]],
#
#        [[374, 613]],
#
#        [[375, 614]],
#
#        [[375, 618]],
#
#        [[373, 620]],
#
#        [[368, 620]],
#
#        [[367, 621]],
#
#        [[366, 621]],
#
#        [[365, 622]],
#
#        [[366, 623]],
#
#        [[368, 623]],
#
#        [[369, 624]],
#
#        [[370, 624]],
#
#        [[371, 625]],
#
#        [[373, 625]],
#
#        [[374, 626]],
#
#        [[377, 626]],
#
#        [[378, 627]],
#
#        [[388, 627]],
#
#        [[389, 626]],
#
#        [[394, 626]],
#
#        [[395, 625]],
#
#        [[401, 625]],
#
#        [[402, 626]],
#
#        [[404, 626]],
#
#        [[405, 627]],
#
#        [[406, 626]],
#
#        [[404, 624]],
#
#        [[404, 622]],
#
#        [[403, 621]],
#
#        [[400, 621]],
#
#        [[399, 622]],
#
#        [[394, 622]],
#
#        [[393, 621]],
#
#        [[391, 621]],
#
#        [[389, 619]],
#
#        [[389, 610]],
#
#        [[386, 607]],
#
#        [[386, 605]],
#
#        [[387, 604]],
#
#        [[387, 603]],
#
#        [[386, 602]],
#
#        [[386, 598]],
#
#        [[385, 597]],
#
#        [[385, 595]],
#
#        [[384, 594]],
#
#        [[384, 592]],
#
#        [[383, 591]],
#
#        [[383, 590]],
#
#        [[382, 589]],
#
#        [[382, 586]]], dtype=int32), array([[[384, 596]],
#
#        [[385, 597]],
#
#        [[385, 598]],
#
#        [[384, 599]],
#
#        [[383, 599]],
#
#        [[382, 598]]], dtype=int32), array([[[383, 593]],
#
#        [[384, 594]],
#
#        [[384, 595]],
#
#        [[382, 597]],
#
#        [[381, 596]],
#
#        [[381, 595]]], dtype=int32), array([[[861, 577]],
#
#        [[859, 579]],
#
#        [[858, 579]],
#
#        [[857, 580]],
#
#        [[856, 580]],
#
#        [[855, 581]],
#
#        [[855, 582]],
#
#        [[854, 583]],
#
#        [[854, 584]],
#
#        [[853, 585]],
#
#        [[853, 586]],
#
#        [[852, 587]],
#
#        [[852, 588]],
#
#        [[851, 589]],
#
#        [[851, 594]],
#
#        [[853, 596]],
#
#        [[853, 599]],
#
#        [[852, 600]],
#
#        [[851, 600]],
#
#        [[850, 601]],
#
#        [[848, 601]],
#
#        [[847, 602]],
#
#        [[846, 602]],
#
#        [[845, 603]],
#
#        [[845, 604]],
#
#        [[850, 604]],
#
#        [[851, 605]],
#
#        [[853, 605]],
#
#        [[854, 606]],
#
#        [[866, 606]],
#
#        [[867, 605]],
#
#        [[869, 605]],
#
#        [[870, 604]],
#
#        [[872, 604]],
#
#        [[873, 603]],
#
#        [[875, 603]],
#
#        [[876, 602]],
#
#        [[877, 602]],
#
#        [[878, 601]],
#
#        [[883, 601]],
#
#        [[883, 600]],
#
#        [[882, 600]],
#
#        [[881, 601]],
#
#        [[875, 601]],
#
#        [[874, 600]],
#
#        [[869, 600]],
#
#        [[866, 597]],
#
#        [[866, 596]],
#
#        [[867, 595]],
#
#        [[867, 594]],
#
#        [[865, 592]],
#
#        [[865, 590]],
#
#        [[864, 589]],
#
#        [[864, 588]],
#
#        [[863, 587]],
#
#        [[863, 584]],
#
#        [[862, 583]],
#
#        [[862, 581]],
#
#        [[861, 580]],
#
#        [[861, 578]],
#
#        [[862, 577]]], dtype=int32), array([[[1195,  568]],
#
#        [[1194,  569]],
#
#        [[1191,  569]],
#
#        [[1190,  570]],
#
#        [[1189,  570]],
#
#        [[1188,  571]],
#
#        [[1186,  571]],
#
#        [[1185,  572]],
#
#        [[1183,  572]],
#
#        [[1180,  575]],
#
#        [[1180,  577]],
#
#        [[1181,  578]],
#
#        [[1181,  580]],
#
#        [[1180,  581]],
#
#        [[1179,  581]],
#
#        [[1178,  582]],
#
#        [[1176,  582]],
#
#        [[1175,  583]],
#
#        [[1174,  583]],
#
#        [[1172,  585]],
#
#        [[1171,  585]],
#
#        [[1174,  585]],
#
#        [[1175,  586]],
#
#        [[1176,  586]],
#
#        [[1177,  587]],
#
#        [[1179,  587]],
#
#        [[1180,  588]],
#
#        [[1186,  588]],
#
#        [[1187,  589]],
#
#        [[1192,  589]],
#
#        [[1193,  588]],
#
#        [[1196,  588]],
#
#        [[1197,  587]],
#
#        [[1201,  587]],
#
#        [[1202,  586]],
#
#        [[1203,  587]],
#
#        [[1204,  586]],
#
#        [[1206,  586]],
#
#        [[1207,  585]],
#
#        [[1208,  585]],
#
#        [[1209,  584]],
#
#        [[1212,  584]],
#
#        [[1211,  583]],
#
#        [[1210,  583]],
#
#        [[1209,  584]],
#
#        [[1208,  583]],
#
#        [[1207,  584]],
#
#        [[1205,  584]],
#
#        [[1204,  583]],
#
#        [[1199,  583]],
#
#        [[1198,  582]],
#
#        [[1197,  582]],
#
#        [[1196,  581]],
#
#        [[1196,  580]],
#
#        [[1197,  579]],
#
#        [[1197,  578]],
#
#        [[1196,  577]],
#
#        [[1196,  573]],
#
#        [[1197,  572]],
#
#        [[1197,  571]],
#
#        [[1200,  568]]], dtype=int32), array([[[ 976,  559]],
#
#        [[ 976,  561]],
#
#        [[ 973,  564]],
#
#        [[ 972,  563]],
#
#        [[ 973,  564]],
#
#        [[ 973,  565]],
#
#        [[ 972,  566]],
#
#        [[ 972,  578]],
#
#        [[ 975,  581]],
#
#        [[ 975,  582]],
#
#        [[ 976,  583]],
#
#        [[ 974,  585]],
#
#        [[ 973,  585]],
#
#        [[ 972,  586]],
#
#        [[ 970,  586]],
#
#        [[ 969,  587]],
#
#        [[ 968,  587]],
#
#        [[ 966,  589]],
#
#        [[ 965,  589]],
#
#        [[ 970,  589]],
#
#        [[ 971,  590]],
#
#        [[ 972,  590]],
#
#        [[ 973,  591]],
#
#        [[ 976,  591]],
#
#        [[ 977,  592]],
#
#        [[ 978,  592]],
#
#        [[ 979,  593]],
#
#        [[ 979,  596]],
#
#        [[ 980,  597]],
#
#        [[ 980,  599]],
#
#        [[ 981,  600]],
#
#        [[ 981,  601]],
#
#        [[ 986,  606]],
#
#        [[ 990,  606]],
#
#        [[ 991,  607]],
#
#        [[ 992,  606]],
#
#        [[ 992,  604]],
#
#        [[ 993,  603]],
#
#        [[ 993,  602]],
#
#        [[ 994,  601]],
#
#        [[ 994,  600]],
#
#        [[ 995,  599]],
#
#        [[ 995,  594]],
#
#        [[ 994,  594]],
#
#        [[ 993,  593]],
#
#        [[ 994,  592]],
#
#        [[ 994,  591]],
#
#        [[ 996,  589]],
#
#        [[ 997,  589]],
#
#        [[ 998,  588]],
#
#        [[1000,  588]],
#
#        [[1001,  587]],
#
#        [[1010,  587]],
#
#        [[1009,  586]],
#
#        [[1009,  584]],
#
#        [[1008,  585]],
#
#        [[ 995,  585]],
#
#        [[ 994,  584]],
#
#        [[ 989,  584]],
#
#        [[ 987,  582]],
#
#        [[ 989,  580]],
#
#        [[ 990,  580]],
#
#        [[ 990,  578]],
#
#        [[ 988,  576]],
#
#        [[ 988,  574]],
#
#        [[ 986,  572]],
#
#        [[ 986,  571]],
#
#        [[ 985,  570]],
#
#        [[ 985,  569]],
#
#        [[ 982,  566]],
#
#        [[ 982,  565]],
#
#        [[ 981,  565]],
#
#        [[ 977,  561]],
#
#        [[ 977,  560]]], dtype=int32), array([[[828, 558]],
#
#        [[827, 559]],
#
#        [[823, 559]],
#
#        [[822, 560]],
#
#        [[820, 560]],
#
#        [[819, 561]],
#
#        [[819, 565]],
#
#        [[818, 566]],
#
#        [[816, 566]],
#
#        [[815, 567]],
#
#        [[814, 567]],
#
#        [[812, 569]],
#
#        [[812, 570]],
#
#        [[816, 570]],
#
#        [[817, 571]],
#
#        [[818, 571]],
#
#        [[819, 572]],
#
#        [[832, 572]],
#
#        [[833, 571]],
#
#        [[839, 571]],
#
#        [[840, 570]],
#
#        [[843, 570]],
#
#        [[843, 569]],
#
#        [[844, 568]],
#
#        [[845, 568]],
#
#        [[846, 567]],
#
#        [[849, 567]],
#
#        [[849, 566]],
#
#        [[837, 566]],
#
#        [[833, 562]],
#
#        [[833, 561]],
#
#        [[836, 558]],
#
#        [[837, 558]]], dtype=int32), array([[[ 33, 537]],
#
#        [[ 32, 538]],
#
#        [[ 32, 539]],
#
#        [[ 31, 540]],
#
#        [[ 31, 542]],
#
#        [[ 30, 543]],
#
#        [[ 30, 545]],
#
#        [[ 29, 546]],
#
#        [[ 29, 557]],
#
#        [[ 30, 558]],
#
#        [[ 30, 560]],
#
#        [[ 31, 561]],
#
#        [[ 31, 562]],
#
#        [[ 32, 563]],
#
#        [[ 32, 566]],
#
#        [[ 30, 568]],
#
#        [[ 28, 568]],
#
#        [[ 27, 569]],
#
#        [[ 25, 569]],
#
#        [[ 24, 570]],
#
#        [[ 25, 571]],
#
#        [[ 27, 571]],
#
#        [[ 28, 572]],
#
#        [[ 29, 572]],
#
#        [[ 30, 573]],
#
#        [[ 31, 573]],
#
#        [[ 32, 574]],
#
#        [[ 34, 574]],
#
#        [[ 35, 575]],
#
#        [[ 37, 575]],
#
#        [[ 41, 579]],
#
#        [[ 42, 579]],
#
#        [[ 43, 580]],
#
#        [[ 51, 580]],
#
#        [[ 52, 579]],
#
#        [[ 53, 579]],
#
#        [[ 53, 578]],
#
#        [[ 54, 577]],
#
#        [[ 54, 575]],
#
#        [[ 53, 574]],
#
#        [[ 53, 573]],
#
#        [[ 55, 571]],
#
#        [[ 57, 571]],
#
#        [[ 58, 570]],
#
#        [[ 63, 570]],
#
#        [[ 63, 569]],
#
#        [[ 55, 569]],
#
#        [[ 54, 568]],
#
#        [[ 51, 568]],
#
#        [[ 50, 567]],
#
#        [[ 48, 567]],
#
#        [[ 47, 566]],
#
#        [[ 47, 562]],
#
#        [[ 45, 560]],
#
#        [[ 45, 557]],
#
#        [[ 43, 555]],
#
#        [[ 43, 552]],
#
#        [[ 42, 551]],
#
#        [[ 42, 550]],
#
#        [[ 41, 549]],
#
#        [[ 41, 548]],
#
#        [[ 40, 547]],
#
#        [[ 40, 546]],
#
#        [[ 39, 545]],
#
#        [[ 39, 544]],
#
#        [[ 36, 541]],
#
#        [[ 36, 540]],
#
#        [[ 35, 539]],
#
#        [[ 35, 538]],
#
#        [[ 34, 537]]], dtype=int32), array([[[ 38, 547]],
#
#        [[ 39, 546]],
#
#        [[ 41, 548]],
#
#        [[ 40, 549]],
#
#        [[ 39, 549]],
#
#        [[ 38, 548]]], dtype=int32), array([[[140, 513]],
#
#        [[139, 514]],
#
#        [[135, 514]],
#
#        [[134, 515]],
#
#        [[131, 515]],
#
#        [[130, 516]],
#
#        [[128, 516]],
#
#        [[127, 517]],
#
#        [[126, 517]],
#
#        [[125, 518]],
#
#        [[125, 519]],
#
#        [[128, 519]],
#
#        [[129, 520]],
#
#        [[131, 520]],
#
#        [[132, 521]],
#
#        [[133, 521]],
#
#        [[134, 522]],
#
#        [[135, 522]],
#
#        [[137, 524]],
#
#        [[137, 525]],
#
#        [[141, 529]],
#
#        [[142, 529]],
#
#        [[143, 530]],
#
#        [[144, 530]],
#
#        [[145, 531]],
#
#        [[146, 531]],
#
#        [[148, 533]],
#
#        [[149, 533]],
#
#        [[150, 534]],
#
#        [[152, 534]],
#
#        [[153, 535]],
#
#        [[156, 535]],
#
#        [[157, 534]],
#
#        [[158, 535]],
#
#        [[158, 532]],
#
#        [[157, 531]],
#
#        [[157, 529]],
#
#        [[156, 528]],
#
#        [[156, 527]],
#
#        [[154, 525]],
#
#        [[154, 524]],
#
#        [[153, 523]],
#
#        [[156, 520]],
#
#        [[158, 520]],
#
#        [[159, 519]],
#
#        [[166, 519]],
#
#        [[166, 518]],
#
#        [[165, 517]],
#
#        [[156, 517]],
#
#        [[155, 516]],
#
#        [[153, 516]],
#
#        [[152, 515]],
#
#        [[151, 515]],
#
#        [[150, 514]],
#
# ...
#
#        [[317, 151]],
#
#        [[316, 150]],
#
#        [[316, 145]],
#
#        [[317, 144]],
#
#        [[317, 143]],
#
#        [[316, 142]],
#
#        [[316, 141]],
#
#        [[317, 140]],
#
#        [[316, 139]],
#
#        [[316, 138]],
#
#        [[318, 136]],
#
#        [[319, 136]],
#
#        [[320, 135]],
#
#        [[322, 135]],
#
#        [[323, 134]],
#
#        [[328, 134]],
#
#        [[329, 133]],
#
#        [[330, 133]],
#
#        [[331, 134]],
#
#        [[333, 134]],
#
#        [[333, 130]],
#
#        [[332, 129]],
#
#        [[331, 129]],
#
#        [[330, 130]],
#
#        [[327, 130]],
#
#        [[326, 131]],
#
#        [[323, 131]],
#
#        [[322, 130]],
#
#        [[320, 130]],
#
#        [[319, 129]],
#
#        [[316, 129]],
#
#        [[314, 127]],
#
#        [[313, 127]],
#
#        [[311, 125]],
#
#        [[312, 124]],
#
#        [[312, 123]],
#
#        [[310, 121]],
#
#        [[309, 121]],
#
#        [[306, 118]],
#
#        [[304, 118]],
#
#        [[303, 117]],
#
#        [[301, 117]],
#
#        [[300, 116]],
#
#        [[298, 116]],
#
#        [[297, 115]],
#
#        [[294, 115]],
#
#        [[293, 114]]], dtype=int32), array([[[312, 164]],
#
#        [[313, 163]],
#
#        [[314, 164]],
#
#        [[313, 165]]], dtype=int32), array([[[311, 163]],
#
#        [[312, 162]],
#
#        [[313, 163]],
#
#        [[312, 164]]], dtype=int32), array([[[313, 161]],
#
#        [[314, 160]],
#
#        [[315, 161]],
#
#        [[314, 162]]], dtype=int32), array([[[312, 160]],
#
#        [[313, 159]],
#
#        [[314, 160]],
#
#        [[313, 161]]], dtype=int32), array([[[313, 157]],
#
#        [[314, 156]],
#
#        [[316, 158]],
#
#        [[315, 159]],
#
#        [[314, 159]],
#
#        [[313, 158]]], dtype=int32), array([[[314, 155]],
#
#        [[315, 154]],
#
#        [[316, 155]],
#
#        [[315, 156]]], dtype=int32), array([[[751, 108]],
#
#        [[751, 110]],
#
#        [[750, 111]],
#
#        [[749, 111]],
#
#        [[748, 112]],
#
#        [[749, 113]],
#
#        [[749, 117]],
#
#        [[750, 118]],
#
#        [[748, 120]],
#
#        [[746, 120]],
#
#        [[745, 121]],
#
#        [[744, 121]],
#
#        [[743, 122]],
#
#        [[742, 122]],
#
#        [[743, 122]],
#
#        [[744, 123]],
#
#        [[746, 123]],
#
#        [[749, 126]],
#
#        [[749, 128]],
#
#        [[743, 134]],
#
#        [[743, 135]],
#
#        [[742, 136]],
#
#        [[742, 137]],
#
#        [[741, 138]],
#
#        [[741, 139]],
#
#        [[743, 141]],
#
#        [[743, 144]],
#
#        [[742, 145]],
#
#        [[741, 145]],
#
#        [[740, 146]],
#
#        [[737, 146]],
#
#        [[736, 147]],
#
#        [[735, 147]],
#
#        [[735, 148]],
#
#        [[736, 148]],
#
#        [[737, 149]],
#
#        [[738, 149]],
#
#        [[739, 150]],
#
#        [[740, 150]],
#
#        [[741, 151]],
#
#        [[742, 151]],
#
#        [[743, 152]],
#
#        [[753, 152]],
#
#        [[754, 151]],
#
#        [[756, 151]],
#
#        [[757, 150]],
#
#        [[761, 150]],
#
#        [[762, 149]],
#
#        [[765, 152]],
#
#        [[765, 151]],
#
#        [[766, 150]],
#
#        [[766, 149]],
#
#        [[768, 147]],
#
#        [[773, 147]],
#
#        [[772, 146]],
#
#        [[772, 145]],
#
#        [[770, 145]],
#
#        [[768, 143]],
#
#        [[768, 142]],
#
#        [[769, 141]],
#
#        [[769, 132]],
#
#        [[770, 131]],
#
#        [[770, 129]],
#
#        [[769, 128]],
#
#        [[769, 127]],
#
#        [[770, 126]],
#
#        [[771, 126]],
#
#        [[772, 125]],
#
#        [[773, 125]],
#
#        [[774, 124]],
#
#        [[776, 124]],
#
#        [[777, 123]],
#
#        [[779, 123]],
#
#        [[780, 122]],
#
#        [[782, 122]],
#
#        [[783, 123]],
#
#        [[785, 123]],
#
#        [[785, 122]],
#
#        [[784, 121]],
#
#        [[783, 121]],
#
#        [[782, 122]],
#
#        [[778, 122]],
#
#        [[777, 121]],
#
#        [[774, 121]],
#
#        [[773, 120]],
#
#        [[770, 120]],
#
#        [[765, 115]],
#
#        [[765, 114]],
#
#        [[764, 114]],
#
#        [[763, 113]],
#
#        [[763, 112]],
#
#        [[762, 111]],
#
#        [[761, 111]],
#
#        [[760, 110]],
#
#        [[758, 110]],
#
#        [[757, 109]],
#
#        [[753, 109]],
#
#        [[752, 108]]], dtype=int32), array([[[476,  96]],
#
#        [[475,  97]],
#
#        [[469,  97]],
#
#        [[468,  98]],
#
#        [[467,  98]],
#
#        [[467, 100]],
#
#        [[465, 102]],
#
#        [[463, 102]],
#
#        [[462, 103]],
#
#        [[461, 103]],
#
#        [[460, 104]],
#
#        [[459, 104]],
#
#        [[458, 105]],
#
#        [[459, 106]],
#
#        [[461, 106]],
#
#        [[462, 107]],
#
#        [[464, 107]],
#
#        [[465, 108]],
#
#        [[467, 108]],
#
#        [[468, 109]],
#
#        [[469, 109]],
#
#        [[470, 110]],
#
#        [[470, 111]],
#
#        [[471, 112]],
#
#        [[471, 113]],
#
#        [[472, 113]],
#
#        [[475, 116]],
#
#        [[476, 116]],
#
#        [[477, 117]],
#
#        [[479, 117]],
#
#        [[481, 119]],
#
#        [[482, 119]],
#
#        [[483, 120]],
#
#        [[485, 120]],
#
#        [[486, 121]],
#
#        [[488, 121]],
#
#        [[489, 120]],
#
#        [[490, 120]],
#
#        [[491, 121]],
#
#        [[493, 121]],
#
#        [[494, 122]],
#
#        [[494, 121]],
#
#        [[491, 118]],
#
#        [[491, 117]],
#
#        [[489, 115]],
#
#        [[489, 114]],
#
#        [[486, 111]],
#
#        [[486, 109]],
#
#        [[489, 106]],
#
#        [[490, 106]],
#
#        [[491, 105]],
#
#        [[500, 105]],
#
#        [[500, 104]],
#
#        [[499, 103]],
#
#        [[490, 103]],
#
#        [[489, 102]],
#
#        [[487, 102]],
#
#        [[482,  97]],
#
#        [[482,  96]]], dtype=int32), array([[[419,  78]],
#
#        [[419,  79]],
#
#        [[418,  80]],
#
#        [[418,  81]],
#
#        [[417,  82]],
#
#        [[415,  82]],
#
#        [[415,  86]],
#
#        [[414,  87]],
#
#        [[414,  93]],
#
#        [[413,  94]],
#
#        [[413,  97]],
#
#        [[414,  98]],
#
#        [[414, 101]],
#
#        [[415, 102]],
#
#        [[415, 103]],
#
#        [[416, 103]],
#
#        [[417, 104]],
#
#        [[417, 105]],
#
#        [[418, 106]],
#
#        [[418, 108]],
#
#        [[416, 110]],
#
#        [[412, 110]],
#
#        [[411, 111]],
#
#        [[410, 111]],
#
#        [[409, 112]],
#
#        [[408, 112]],
#
#        [[408, 113]],
#
#        [[409, 113]],
#
#        [[410, 114]],
#
#        [[412, 114]],
#
#        [[413, 115]],
#
#        [[415, 115]],
#
#        [[416, 116]],
#
#        [[417, 116]],
#
#        [[418, 117]],
#
#        [[420, 117]],
#
#        [[421, 118]],
#
#        [[421, 119]],
#
#        [[423, 121]],
#
#        [[423, 122]],
#
#        [[424, 123]],
#
#        [[424, 124]],
#
#        [[425, 124]],
#
#        [[428, 127]],
#
#        [[429, 127]],
#
#        [[430, 128]],
#
#        [[431, 128]],
#
#        [[432, 129]],
#
#        [[433, 129]],
#
#        [[434, 130]],
#
#        [[440, 130]],
#
#        [[440, 126]],
#
#        [[441, 125]],
#
#        [[441, 124]],
#
#        [[440, 123]],
#
#        [[440, 122]],
#
#        [[439, 121]],
#
#        [[439, 117]],
#
#        [[438, 116]],
#
#        [[441, 113]],
#
#        [[442, 113]],
#
#        [[443, 112]],
#
#        [[445, 112]],
#
#        [[446, 111]],
#
#        [[451, 111]],
#
#        [[452, 110]],
#
#        [[453, 111]],
#
#        [[454, 111]],
#
#        [[453, 110]],
#
#        [[453, 109]],
#
#        [[452, 108]],
#
#        [[449, 108]],
#
#        [[448, 109]],
#
#        [[439, 109]],
#
#        [[438, 108]],
#
#        [[436, 108]],
#
#        [[435, 107]],
#
#        [[434, 107]],
#
#        [[433, 106]],
#
#        [[434, 105]],
#
#        [[434, 102]],
#
#        [[433, 101]],
#
#        [[432, 101]],
#
#        [[430,  99]],
#
#        [[431,  98]],
#
#        [[432,  98]],
#
#        [[431,  97]],
#
#        [[431,  96]],
#
#        [[428,  93]],
#
#        [[428,  91]],
#
#        [[427,  90]],
#
#        [[427,  89]],
#
#        [[425,  87]],
#
#        [[425,  86]],
#
#        [[420,  81]],
#
#        [[420,  80]],
#
#        [[419,  79]]], dtype=int32), array([[[ 963,   72]],
#
#        [[ 962,   73]],
#
#        [[ 961,   73]],
#
#        [[ 960,   74]],
#
#        [[ 958,   74]],
#
#        [[ 957,   75]],
#
#        [[ 956,   75]],
#
#        [[ 955,   76]],
#
#        [[ 954,   76]],
#
#        [[ 952,   78]],
#
#        [[ 951,   78]],
#
#        [[ 949,   80]],
#
#        [[ 948,   80]],
#
#        [[ 948,   81]],
#
#        [[ 947,   82]],
#
#        [[ 947,   83]],
#
#        [[ 946,   84]],
#
#        [[ 946,   85]],
#
#        [[ 948,   87]],
#
#        [[ 948,   89]],
#
#        [[ 946,   91]],
#
#        [[ 942,   91]],
#
#        [[ 939,   94]],
#
#        [[ 941,   94]],
#
#        [[ 942,   95]],
#
#        [[ 944,   95]],
#
#        [[ 945,   96]],
#
#        [[ 946,   96]],
#
#        [[ 947,   97]],
#
#        [[ 950,   97]],
#
#        [[ 951,   98]],
#
#        [[ 958,   98]],
#
#        [[ 959,   97]],
#
#        [[ 962,   97]],
#
#        [[ 963,   96]],
#
#        [[ 965,   96]],
#
#        [[ 966,   95]],
#
#        [[ 967,   95]],
#
#        [[ 968,   94]],
#
#        [[ 970,   94]],
#
#        [[ 971,   93]],
#
#        [[ 973,   93]],
#
#        [[ 974,   92]],
#
#        [[ 978,   92]],
#
#        [[ 979,   93]],
#
#        [[ 983,   93]],
#
#        [[ 984,   94]],
#
#        [[ 986,   94]],
#
#        [[ 987,   95]],
#
#        [[ 988,   95]],
#
#        [[ 989,   96]],
#
#        [[ 991,   96]],
#
#        [[ 992,   97]],
#
#        [[ 996,   97]],
#
#        [[ 997,   96]],
#
#        [[ 999,   96]],
#
#        [[1000,   95]],
#
#        [[1006,   95]],
#
#        [[1007,   94]],
#
#        [[1011,   94]],
#
#        [[1013,   92]],
#
#        [[1017,   92]],
#
#        [[1014,   92]],
#
#        [[1013,   91]],
#
#        [[1010,   91]],
#
#        [[1009,   90]],
#
#        [[1009,   89]],
#
#        [[1011,   87]],
#
#        [[1019,   87]],
#
#        [[1020,   88]],
#
#        [[1021,   87]],
#
#        [[1021,   85]],
#
#        [[1020,   84]],
#
#        [[1020,   83]],
#
#        [[1019,   82]],
#
#        [[1020,   81]],
#
#        [[1020,   80]],
#
#        [[1017,   80]],
#
#        [[1016,   81]],
#
#        [[1015,   81]],
#
#        [[1014,   82]],
#
#        [[1012,   82]],
#
#        [[1011,   83]],
#
#        [[1004,   83]],
#
#        [[1003,   82]],
#
#        [[1003,   80]],
#
#        [[1005,   78]],
#
#        [[1007,   78]],
#
#        [[1008,   77]],
#
#        [[1011,   77]],
#
#        [[1007,   77]],
#
#        [[1006,   76]],
#
#        [[1003,   76]],
#
#        [[1002,   77]],
#
#        [[ 996,   77]],
#
#        [[ 995,   78]],
#
#        [[ 989,   78]],
#
#        [[ 988,   79]],
#
#        [[ 986,   79]],
#
#        [[ 983,   82]],
#
#        [[ 984,   83]],
#
#        [[ 984,   85]],
#
#        [[ 982,   87]],
#
#        [[ 981,   87]],
#
#        [[ 980,   88]],
#
#        [[ 977,   88]],
#
#        [[ 976,   89]],
#
#        [[ 975,   89]],
#
#        [[ 973,   91]],
#
#        [[ 970,   91]],
#
#        [[ 969,   90]],
#
#        [[ 968,   90]],
#
#        [[ 967,   89]],
#
#        [[ 965,   89]],
#
#        [[ 963,   87]],
#
#        [[ 964,   86]],
#
#        [[ 964,   84]],
#
#        [[ 962,   82]],
#
#        [[ 962,   81]],
#
#        [[ 961,   80]],
#
#        [[ 962,   79]],
#
#        [[ 962,   78]],
#
#        [[ 963,   77]],
#
#        [[ 963,   75]],
#
#        [[ 965,   73]],
#
#        [[ 965,   72]]], dtype=int32), array([[[918,  54]],
#
#        [[917,  55]],
#
#        [[916,  55]],
#
#        [[914,  57]],
#
#        [[913,  57]],
#
#        [[912,  58]],
#
#        [[911,  58]],
#
#        [[909,  60]],
#
#        [[908,  60]],
#
#        [[907,  61]],
#
#        [[906,  61]],
#
#        [[905,  62]],
#
#        [[905,  63]],
#
#        [[904,  64]],
#
#        [[904,  65]],
#
#        [[903,  66]],
#
#        [[904,  67]],
#
#        [[904,  68]],
#
#        [[905,  69]],
#
#        [[905,  71]],
#
#        [[903,  73]],
#
#        [[900,  73]],
#
#        [[899,  74]],
#
#        [[897,  74]],
#
#        [[896,  75]],
#
#        [[895,  75]],
#
#        [[894,  76]],
#
#        [[893,  76]],
#
#        [[894,  76]],
#
#        [[895,  77]],
#
#        [[897,  77]],
#
#        [[898,  78]],
#
#        [[901,  78]],
#
#        [[902,  79]],
#
#        [[903,  79]],
#
#        [[904,  80]],
#
#        [[910,  80]],
#
#        [[911,  81]],
#
#        [[912,  81]],
#
#        [[913,  80]],
#
#        [[920,  80]],
#
#        [[921,  79]],
#
#        [[922,  79]],
#
#        [[923,  80]],
#
#        [[930,  80]],
#
#        [[928,  78]],
#
#        [[930,  76]],
#
#        [[931,  76]],
#
#        [[932,  75]],
#
#        [[939,  75]],
#
#        [[939,  73]],
#
#        [[926,  73]],
#
#        [[925,  72]],
#
#        [[923,  72]],
#
#        [[922,  71]],
#
#        [[922,  68]],
#
#        [[921,  67]],
#
#        [[921,  62]],
#
#        [[923,  60]],
#
#        [[923,  59]],
#
#        [[924,  58]],
#
#        [[924,  57]],
#
#        [[926,  55]],
#
#        [[926,  54]],
#
#        [[925,  54]],
#
#        [[924,  55]],
#
#        [[920,  55]],
#
#        [[919,  54]]], dtype=int32), array([[[557,   6]],
#
#        [[556,   7]],
#
#        [[553,   7]],
#
#        [[552,   8]],
#
#        [[550,   8]],
#
#        [[549,   9]],
#
#        [[547,   9]],
#
#        [[544,  12]],
#
#        [[544,  13]],
#
#        [[545,  14]],
#
#        [[545,  15]],
#
#        [[546,  16]],
#
#        [[544,  18]],
#
#        [[543,  18]],
#
#        [[542,  19]],
#
#        [[541,  19]],
#
#        [[540,  20]],
#
#        [[539,  20]],
#
#        [[536,  23]],
#
#        [[535,  23]],
#
#        [[538,  23]],
#
#        [[539,  24]],
#
#        [[541,  24]],
#
#        [[542,  25]],
#
#        [[544,  25]],
#
#        [[545,  26]],
#
#        [[559,  26]],
#
#        [[560,  25]],
#
#        [[563,  25]],
#
#        [[564,  24]],
#
#        [[566,  24]],
#
#        [[567,  23]],
#
#        [[572,  23]],
#
#        [[573,  22]],
#
#        [[576,  22]],
#
#        [[577,  23]],
#
#        [[579,  23]],
#
#        [[579,  22]],
#
#        [[578,  21]],
#
#        [[578,  19]],
#
#        [[574,  19]],
#
#        [[573,  20]],
#
#        [[570,  20]],
#
#        [[569,  19]],
#
#        [[566,  19]],
#
#        [[563,  16]],
#
#        [[563,  15]],
#
#        [[561,  13]],
#
#        [[561,  11]],
#
#        [[565,   7]],
#
#        [[566,   7]],
#
#        [[567,   6]],
#
#        [[561,   6]],
#
#        [[560,   7]],
#
#        [[559,   6]]], dtype=int32), array([[[722,   0]],
#
#        [[722,   9]],
#
#        [[721,  10]],
#
#        [[721,  15]],
#
#        [[722,  16]],
#
#        [[722,  18]],
#
#        [[724,  20]],
#
#        [[724,  21]],
#
#        [[725,  22]],
#
#        [[725,  26]],
#
#        [[723,  28]],
#
#        [[721,  28]],
#
#        [[720,  29]],
#
#        [[719,  29]],
#
#        [[716,  32]],
#
#        [[720,  32]],
#
#        [[721,  33]],
#
#        [[726,  33]],
#
#        [[731,  38]],
#
#        [[732,  38]],
#
#        [[734,  40]],
#
#        [[743,  40]],
#
#        [[744,  39]],
#
#        [[744,  38]],
#
#        [[745,  37]],
#
#        [[745,  31]],
#
#        [[747,  29]],
#
#        [[748,  29]],
#
#        [[750,  27]],
#
#        [[751,  27]],
#
#        [[752,  26]],
#
#        [[759,  26]],
#
#        [[760,  25]],
#
#        [[759,  24]],
#
#        [[759,  23]],
#
#        [[757,  23]],
#
#        [[756,  24]],
#
#        [[753,  24]],
#
#        [[752,  25]],
#
#        [[749,  25]],
#
#        [[748,  24]],
#
#        [[744,  24]],
#
#        [[743,  23]],
#
#        [[742,  23]],
#
#        [[741,  22]],
#
#        [[741,  21]],
#
#        [[742,  20]],
#
#        [[742,  19]],
#
#        [[741,  19]],
#
#        [[740,  18]],
#
#        [[740,  16]],
#
#        [[739,  15]],
#
#        [[739,  13]],
#
#        [[738,  12]],
#
#        [[738,  11]],
#
#        [[737,  10]],
#
#        [[737,   9]],
#
#        [[736,   8]],
#
#        [[736,   6]],
#
#        [[735,   5]],
#
#        [[735,   4]],
#
#        [[734,   3]],
#
#        [[734,   2]],
#
#        [[733,   1]],
#
#        [[733,   0]],
#
#        [[732,   0]],
#
#        [[732,   1]],
#
#        [[731,   2]],
#
#        [[730,   1]],
#
#        [[730,   0]]], dtype=int32), array([[[733,   5]],
#
#        [[734,   4]],
#
#        [[735,   5]],
#
#        [[735,   6]],
#
#        [[734,   7]],
#
#        [[733,   6]]], dtype=int32), array([[[732,   3]],
#
#        [[733,   2]],
#
#        [[734,   3]],
#
#        [[733,   4]]], dtype=int32), array([[[487,   0]],
#
#        [[488,   1]],
#
#        [[488,   2]],
#
#        [[485,   5]],
#
#        [[481,   5]],
#
#        [[480,   6]],
#
#        [[479,   6]],
#
#        [[478,   7]],
#
#        [[477,   7]],
#
#        [[478,   8]],
#
#        [[479,   8]],
#
#        [[480,   9]],
#
#        [[483,   9]],
#
#        [[484,  10]],
#
#        [[486,  10]],
#
#        [[487,  11]],
#
#        [[492,  11]],
#
#        [[493,  12]],
#
#        [[494,  12]],
#
#        [[495,  13]],
#
#        [[500,  13]],
#
#        [[501,  14]],
#
#        [[502,  14]],
#
#        [[503,  13]],
#
#        [[504,  14]],
#
#        [[511,  14]],
#
#        [[512,  13]],
#
#        [[513,  13]],
#
#        [[511,  13]],
#
#        [[508,  10]],
#
#        [[508,   9]],
#
#        [[509,   8]],
#
#        [[510,   8]],
#
#        [[511,   7]],
#
#        [[514,   7]],
#
#        [[515,   6]],
#
#        [[520,   6]],
#
#        [[520,   5]],
#
#        [[519,   4]],
#
#        [[516,   4]],
#
#        [[515,   5]],
#
#        [[513,   5]],
#
#        [[512,   4]],
#
#        [[507,   4]],
#
#        [[506,   3]],
#
#        [[505,   3]],
#
#        [[503,   1]],
#
#        [[503,   0]]], dtype=int32))
# -1

# %% [markdown]
# image_path = os.path.join(path,'images','parrot.png')
# img = cv2.imread(image_path)

# %% [markdown]
# Reading Video

# %%
video_path = os.path.join(path,'videos','Monkey.mp4')
video = cv2.VideoCapture(video_path)


# Visualizing videos
ret = True
while ret:
    ret, frame = video.read()
    
    if ret:
        cv2.imshow('image',frame)
        cv2.waitKey(50)

video.release()
cv2.destroyAllWindows()

# %%
#Reading from webcam

webcam = cv2.VideoCapture(0)

while True:
    ret, frame = webcam.read()

    cv2.imshow('frame',frame)
    if cv2.waitKey(40) & 0xFF == ord('q'):
        break
    
webcam.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[8], line 8
#       5 while True:
#       6     ret, frame = webcam.read()
# ----> 8     cv2.imshow('frame',frame)
#       9     if cv2.waitKey(40) & 0xFF == ord('q'):
#      10         break
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:973: error: (-215:Assertion failed) size.width>0 && size.height>0 in function 'cv::imshow'
